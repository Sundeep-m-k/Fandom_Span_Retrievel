# %%
import pandas as pd

df = pd.read_csv("/home/sundeep/Fandom-Span-Identification-and-Retrieval/1.Fandom_Dataset_Collection/raw_data/alldimensions_fandom_data/master_spans_alldimensions.csv")
print(df.shape)     # rows, columns
# Out:
# (503654, 13)
# /tmp/ipykernel_2584476/765131635.py:3: DtypeWarning: Columns (8) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("/home/sundeep/Fandom-Span-Identification-and-Retrieval/1.Fandom_Dataset_Collection/raw_data/alldimensions_fandom_data/master_spans_alldimensions.csv")
